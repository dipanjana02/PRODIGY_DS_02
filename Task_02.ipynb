# %%
#importing libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
train_data = pd.read_csv("C:\\Users\\DELL\\Desktop\\train_data.csv")
train_data.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
train_data.describe()
# Out:
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   889.000000  889.000000  889.000000  889.000000  889.000000
# mean    446.000000    0.382452    2.311586   29.642093    0.524184
# std     256.998173    0.486260    0.834700   12.968346    1.103705
# min       1.000000    0.000000    1.000000    0.420000    0.000000
# 25%     224.000000    0.000000    2.000000   22.000000    0.000000
# 50%     446.000000    0.000000    3.000000   29.642093    0.000000
# 75%     668.000000    1.000000    3.000000   35.000000    1.000000
# max     891.000000    1.000000    3.000000   80.000000    8.000000
#
#             Parch        Fare
# count  889.000000  889.000000
# mean     0.382452   32.096681
# std      0.806761   49.697504
# min      0.000000    0.000000
# 25%      0.000000    7.895800
# 50%      0.000000   14.454200
# 75%      0.000000   31.000000
# max      6.000000  512.329200

# %%
test_data = pd.read_csv("C:\\Users\\DELL\\Desktop\\test_data.csv")
test_data.head()
# Out:
#    PassengerId  Pclass                                          Name     Sex  \
# 0          892       3                              Kelly, Mr. James    male
# 1          893       3              Wilkes, Mrs. James (Ellen Needs)  female
# 2          894       2                     Myles, Mr. Thomas Francis    male
# 3          895       3                              Wirz, Mr. Albert    male
# 4          896       3  Hirvonen, Mrs. Alexander (Helga E Lindqvist)  female
#
#     Age  SibSp  Parch   Ticket     Fare Cabin Embarked
# 0  34.5      0      0   330911   7.8292   NaN        Q
# 1  47.0      1      0   363272   7.0000   NaN        S
# 2  62.0      0      0   240276   9.6875   NaN        Q
# 3  27.0      0      0   315154   8.6625   NaN        S
# 4  22.0      1      1  3101298  12.2875   NaN        S

# %%
women = train_data.loc[train_data.Sex == 'female']["Survived"]
rate_women = sum(women)/len(women)

print("% of women who survived:", rate_women)
# Out:
# % of women who survived: 0.7420382165605095

# %%
men = train_data.loc[train_data.Sex == 'male']["Survived"]
rate_men = sum(men)/len(men)

print("% of men who survived:", rate_men)
# Out:
# % of men who survived: 0.18890814558058924

# %%
#Checking whether there is any missing data
train_data.isnull().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# dtype: int64

# %%
sns.heatmap(train_data.isnull())
# Out:
# <Axes: >

# %%
#Inplacing the missing data
train_data.dropna(subset=["Embarked"], inplace=True)
train_data["Cabin"].fillna("Unknown", inplace=True)
train_data["Age"].fillna(train_data["Age"].mean(), inplace=True)

# %%
train_data.isnull().sum()
# Out:
# PassengerId    0
# Survived       0
# Pclass         0
# Name           0
# Sex            0
# Age            0
# SibSp          0
# Parch          0
# Ticket         0
# Fare           0
# Cabin          0
# Embarked       0
# dtype: int64

# %%
train_data.duplicated().sum()
# Out:
# 0

# %%
sns.countplot(x="Survived",data=train_data)
# Out:
# <Axes: xlabel='Survived', ylabel='count'>

# %%
sns.countplot(x='Survived' , data=train_data , hue='Sex' , palette='pastel')
# Out:
# <Axes: xlabel='Survived', ylabel='count'>

# %%
sns.countplot(x="Survived",data=train_data,hue="Pclass",palette="rainbow")
# Out:
# <Axes: xlabel='Survived', ylabel='count'>

# %%
sns.countplot(x="SibSp",data=train_data)
# Out:
# <Axes: xlabel='SibSp', ylabel='count'>

# %%
pd.crosstab([train_data.Sex,train_data.Survived],train_data.Pclass,margins=True).style.background_gradient(cmap='summer_r')
# Out:
# <style type="text/css">
# #T_02769_row0_col0, #T_02769_row0_col1, #T_02769_row0_col3, #T_02769_row3_col2 {
#   background-color: #ffff66;
#   color: #000000;
# }
# #T_02769_row0_col2, #T_02769_row1_col2 {
#   background-color: #f1f866;
#   color: #000000;
# }
# #T_02769_row1_col0 {
#   background-color: #97cb66;
#   color: #000000;
# }
# #T_02769_row1_col1 {
#   background-color: #a3d166;
#   color: #000000;
# }
# #T_02769_row1_col3 {
#   background-color: #d0e866;
#   color: #000000;
# }
# #T_02769_row2_col0 {
#   background-color: #a6d266;
#   color: #000000;
# }
# #T_02769_row2_col1, #T_02769_row2_col3 {
#   background-color: #85c266;
#   color: #000000;
# }
# #T_02769_row2_col2 {
#   background-color: #6eb666;
#   color: #f1f1f1;
# }
# #T_02769_row3_col0 {
#   background-color: #cde666;
#   color: #000000;
# }
# #T_02769_row3_col1 {
#   background-color: #f0f866;
#   color: #000000;
# }
# #T_02769_row3_col3 {
#   background-color: #f7fb66;
#   color: #000000;
# }
# ...

# %%
sns.displot(train_data,kind= "ecdf")
# Out:
# C:\Users\DELL\anaconda3\Lib\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %%
sns.boxplot(x="Pclass",y="Age",data=train_data)
# Out:
# <Axes: xlabel='Pclass', ylabel='Age'>

# %%
y=train_data.Survived
y
# Out:
# 0      0
# 1      1
# 2      1
# 3      1
# 4      0
#       ..
# 886    0
# 887    1
# 888    0
# 889    1
# 890    0
# Name: Survived, Length: 891, dtype: int64

# %%
plt.figure(figsize=(6, 3))
sns.scatterplot(data=train_data, x="Age", y="Fare", hue="Survived")
plt.title("Scatter Plot of Age vs Fare")
plt.xlabel("Age")
plt.ylabel("Fare")
plt.legend(title="Survived")
plt.show()
